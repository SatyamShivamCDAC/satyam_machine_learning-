# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
#Without Scaling

glasses = pd.read_csv('../Cases/Glass_Identification/Glass.csv')

lr = LabelEncoder()

X = glasses.drop('Type',axis=1)
y = lr.fit_transform(glasses['Type'])

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=25,stratify=y)

score=[]

for k in range(1,11):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    y_pred = knn.predict(X_test)
    score.append([k,accuracy_score(y_pred,y_test)])

score = pd.DataFrame(score,columns=["k",'score'])
score.sort_values('score',ascending=False)
# Out:
#     k     score
# 0   1  0.753846
# 1   2  0.753846
# 2   3  0.723077
# 3   4  0.723077
# 4   5  0.723077
# 5   6  0.723077
# 7   8  0.707692
# 6   7  0.692308
# 8   9  0.692308
# 9  10  0.676923

# %%
#With Scaling
scaler = StandardScaler() 
glasses = pd.read_csv('../Cases/Glass_Identification/Glass.csv')

lr = LabelEncoder()

X = glasses.drop('Type',axis=1)
y = lr.fit_transform(glasses['Type'])

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=25,stratify=y)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

score=[]

for k in range(1,11):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled,y_train)
    y_pred = knn.predict(X_test_scaled)
    score.append([k,accuracy_score(y_pred,y_test)])

score = pd.DataFrame(score,columns=["k",'score'])
score.sort_values('score',ascending=False)
# Out:
#     k     score
# 1   2  0.815385
# 0   1  0.800000
# 2   3  0.753846
# 3   4  0.738462
# 5   6  0.692308
# 6   7  0.692308
# 4   5  0.676923
# 7   8  0.661538
# 8   9  0.661538
# 9  10  0.646154

# %%
#With Scaling
scaler = StandardScaler() 
glasses = pd.read_csv('../Cases/Glass_Identification/Glass.csv')

lr = LabelEncoder()

X = glasses.drop('Type',axis=1)
y = lr.fit_transform(glasses['Type'])
y = glasses['Type']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=23)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

score=[]


knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train_scaled,y_train)
y_pred = knn.predict(X_test_scaled)
print(classification_report(y_pred,y_test))
glasses['Type'].value_counts()
# Out:
#                                       precision    recall  f1-score   support
#
#     building_windows_float_processed       0.86      0.64      0.73        28
# building_windows_non_float_processed       0.70      0.79      0.75        24
#                           containers       0.67      0.50      0.57         4
#                            headlamps       0.83      0.83      0.83         6
#                            tableware       0.50      1.00      0.67         2
#      vehicle_windows_float_processed       0.00      0.00      0.00         1
#
#                             accuracy                           0.71        65
#                            macro avg       0.59      0.63      0.59        65
#                         weighted avg       0.76      0.71      0.72        65
# Type
# building_windows_non_float_processed    76
# building_windows_float_processed        70
# headlamps                               29
# vehicle_windows_float_processed         17
# containers                              13
# tableware                                9
# Name: count, dtype: int64
