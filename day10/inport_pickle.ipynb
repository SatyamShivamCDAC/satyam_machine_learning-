# %%
import pickle
import pandas as pd

# %% [markdown]
# <h1>Desialization</h1>

# %%
infile = open('best_random_forest.pkl','rb')
objLoad = pickle.load(infile) #deserialization
infile.close()

tst = pd.read_csv('../Cases/Concrete_Strength/testConcrete.csv') 
objLoad.predict(tst)
# Out:
# array([63.12738   , 40.303     , 36.0613    , 40.924     , 62.11201667,
#        29.963     , 50.51105   , 60.91789167, 57.4163    , 51.1148    ,
#        45.7678    , 53.0227    , 46.1527    , 39.5683    ])
